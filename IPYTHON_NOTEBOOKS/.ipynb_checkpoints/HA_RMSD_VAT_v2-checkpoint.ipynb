# %% [markdown]
# ### Displaying distance matrices

# %% [markdown]
# Read csv tables and display distrance matrices among objects (i.e. RMSD values between all proteins)

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/johnny/github_home/BioInfoTools/IPYTHON_NOTEBOOKS/data/models_v2/RMSD.csv')

df = df.pivot(index='pid1', columns='pid2', values='rmsd')
df = table.fillna(0)
df


#Merging data from mapping
#data = pd.merge(maps_c, df_c, right_on=selection_c.index, left_on=maps_c.index, how='inner')
#data = data.rename(columns={'key_0':'p_id'})
#data = data.set_index(['p_id'])

# Ordering by serotype and repositioning columns with respect to new row position
#data = data.sort(['sero',], ascending=[0])
#data = data.reindex(columns=data.index)
# Out:
# pid2      AAA43090  AAA43117  AAA43185  AAA43205  AAA43243  AAA43247  \
# pid1
# AAA43090      0.00      1.22      0.91      1.36      1.08      0.68
# AAA43117      1.22      0.00      1.65      1.85      1.52      1.30
# AAA43185      0.91      1.65      0.00      1.33      0.89      0.63
# AAA43205      1.36      1.85      1.33      0.00      1.09      1.18
# AAA43243      1.08      1.52      0.89      1.09      0.00      0.83
# AAA43247      0.68      1.30      0.63      1.18      0.83      0.00
# AAA43248      1.04      0.94      1.32      1.59      1.19      1.00
# AAA43578      1.94      2.38      1.54      1.74      1.63      1.59
# AAA43678      1.57      2.15      1.42      1.45      1.38      1.45
# AAA72339      1.66      2.12      1.74      1.27      1.37      1.40
# AAA92280      1.56      2.12      1.45      1.23      1.29      1.43
# AAC54377      2.36      2.40      2.42      2.50      2.42      2.34
# AAC54378      1.17      1.72      1.05      0.84      1.18      0.91
# AAC54380      2.21      2.26      2.48      2.58      2.43      2.23
# AAC59602      2.10      2.08      2.11      2.45      2.20      2.12
# AAD05216      2.38      2.69      2.31      2.26      2.18      2.18
# AAD05217      2.15      2.77      2.13      2.03      1.98      2.03
# AAD05218      2.11      2.61      1.97      1.98      1.90      2.00
# AAD17229      1.49      1.90      1.66      1.45      1.42      1.40
# AAD25309      1.80      2.27      1.64      1.47      1.58      1.58
# AAD25312      1.89      2.03      2.23      2.13      2.17      1.97
# AAD26938      2.42      2.45      2.66      2.83      2.64      2.50
# AAF87283      1.94      2.23      1.96      1.81      1.87      1.75
# AAF87284      2.35      2.62      2.02      1.88      1.86      2.12
# AAG10650      2.27      2.17      2.47      2.59      2.45      2.29
# AAG10670      2.21      2.32      2.34      2.49      2.36      2.23
# AAK70452      1.94      2.32      1.83      1.99      1.86      1.97
# AAK70454      2.35      2.57      2.09      2.03      1.92      1.94
# AAK70456      2.38      2.65      2.14      2.07      1.98      2.07
# AAK71687      2.41      2.74      2.27      2.13      2.39      2.29
# ...            ...       ...       ...       ...       ...       ...
# BAN14745      2.25      2.00      2.17      2.33      2.23      2.22
# BAN14747      2.10      2.20      2.00      2.25      2.17      2.02
# BAN42578      2.15      2.63      1.92      1.89      1.82      1.88
# BAN66743      1.76      1.72      1.80      2.08      1.90      1.71
# BAN79067      2.39      2.76      2.26      2.09      2.27      2.14
# BAN81923      2.23      2.59      1.93      1.74      1.75      1.86
# BAO10666      1.70      1.69      1.78      2.07      1.80      1.88
# BAO56967      2.17      2.40      2.11      2.05      2.07      2.10
# BAO74193      2.04      2.61      1.85      1.70      1.78      1.87
# CAA24271      1.96      2.36      2.07      2.25      2.19      2.07
# CAA24272      1.61      1.88      1.57      1.43      1.49      1.44
# CAA29337      1.99      2.17      2.07      2.28      2.11      1.96
# CAA78263      2.38      2.25      2.33      2.59      2.42      2.22
# CAA91080      2.38      2.63      2.22      2.03      1.97      2.08
# CAA91081      1.59      1.86      1.56      1.33      1.47      1.39
# CAB95856      1.86      2.03      1.66      1.63      1.54      1.62
# CAB95857      1.73      1.54      1.89      1.96      1.77      1.79
# CAC18524      2.42      2.69      2.28      2.14      2.36      2.19
# CAC81018      2.08      2.22      2.15      2.41      2.11      2.03
# CAC86610      1.57      2.05      1.29      1.16      1.34      1.39
# CAD20336      2.07      2.26      2.17      2.25      2.20      2.12
# CAP45718      1.88      2.47      1.82      1.78      1.74      1.87
# CAP49183      2.31      2.73      2.23      2.15      2.11      2.12
# CAP49192      2.06      2.36      1.75      1.54      1.62      1.72
# CCD31011      2.13      2.70      1.82      1.79      1.94      1.87
# CCH23216      1.51      1.97      1.47      1.31      1.41      1.32
# CCH23221      1.67      1.60      1.80      1.98      1.88      1.68
# CCQ71947      1.53      1.65      1.58      1.53      1.59      1.56
# CCQ71983      2.36      2.55      2.11      2.07      1.88      2.00
# CDJ79889      2.18      2.30      2.16      2.22      2.23      2.08
#
# pid2      AAA43248  AAA43578  AAA43678  AAA72339    ...     CAD20336  \
# pid1                                                ...
# AAA43090      1.04      1.94      1.57      1.66    ...         2.07
# AAA43117      0.94      2.38      2.15      2.12    ...         2.26
# AAA43185      1.32      1.54      1.42      1.74    ...         2.17
# AAA43205      1.59      1.74      1.45      1.27    ...         2.25
# AAA43243      1.19      1.63      1.38      1.37    ...         2.20
# AAA43247      1.00      1.59      1.45      1.40    ...         2.12
# AAA43248      0.00      1.99      1.78      1.74    ...         2.14
# AAA43578      1.99      0.00      0.51      1.53    ...         2.44
# AAA43678      1.78      0.51      0.00      1.45    ...         2.27
# AAA72339      1.74      1.53      1.45      0.00    ...         2.35
# AAA92280      1.77      1.60      1.44      0.83    ...         2.45
# AAC54377      2.44      2.67      2.47      2.59    ...         1.97
# AAC54378      1.40      1.63      1.46      1.39    ...         2.13
# AAC54380      2.15      2.64      2.52      2.57    ...         1.96
# AAC59602      2.00      2.45      2.33      2.40    ...         1.06
# AAD05216      2.63      1.89      1.72      2.13    ...         2.69
# AAD05217      2.48      1.60      1.43      1.92    ...         2.55
# AAD05218      2.36      1.55      1.37      1.81    ...         2.54
# AAD17229      1.54      1.72      1.61      1.06    ...         2.30
# AAD25309      1.96      1.60      1.52      1.32    ...         2.51
# AAD25312      1.89      1.68      1.57      1.77    ...         2.38
# AAD26938      2.34      2.99      2.80      2.81    ...         2.36
# AAF87283      1.96      1.27      1.15      1.35    ...         2.42
# AAF87284      2.38      1.45      1.17      1.60    ...         2.68
# AAG10650      2.06      2.74      2.58      2.68    ...         2.00
# AAG10670      2.37      2.62      2.42      2.61    ...         1.93
# AAK70452      2.00      1.52      1.53      1.71    ...         2.45
# AAK70454      2.39      1.55      1.43      1.74    ...         2.58
# AAK70456      2.48      1.63      1.47      1.85    ...         2.61
# AAK71687      2.52      1.71      1.61      1.91    ...         2.76
# ...            ...       ...       ...       ...    ...          ...
# BAN14745      2.14      2.60      2.37      2.51    ...         0.90
# BAN14747      2.09      2.51      2.24      2.49    ...         0.91
# BAN42578      2.36      1.12      0.97      1.75    ...         2.52
# BAN66743      1.61      2.30      2.07      1.94    ...         2.14
# BAN79067      2.45      1.64      1.48      2.03    ...         2.74
# BAN81923      2.25      1.14      0.94      1.69    ...         2.51
# BAO10666      1.60      2.28      2.16      1.92    ...         2.23
# BAO56967      2.25      2.35      2.08      2.33    ...         1.21
# BAO74193      2.28      1.16      0.88      1.68    ...         2.46
# CAA24271      2.16      2.46      2.23      2.44    ...         0.93
# CAA24272      1.52      1.80      1.60      1.08    ...         2.17
# CAA29337      2.08      2.38      2.23      2.33    ...         0.93
# CAA78263      2.20      2.58      2.38      2.60    ...         1.78
# CAA91080      2.53      1.78      1.52      1.89    ...         2.58
# CAA91081      1.49      1.78      1.58      0.99    ...         2.15
# CAB95856      1.87      2.11      1.81      1.68    ...         2.19
# CAB95857      1.57      2.29      2.12      1.95    ...         2.22
# CAC18524      2.57      1.78      1.66      2.13    ...         2.74
# CAC81018      2.09      2.46      2.22      2.46    ...         0.89
# CAC86610      1.64      1.44      1.41      0.81    ...         2.38
# CAD20336      2.14      2.44      2.27      2.35    ...         0.00
# CAP45718      2.09      1.20      0.84      1.72    ...         2.34
# CAP49183      2.62      1.75      1.39      2.03    ...         2.70
# CAP49192      2.24      1.84      1.61      1.42    ...         2.60
# CCD31011      2.24      1.25      1.15      1.49    ...         2.46
# CCH23216      1.55      1.44      1.38      0.59    ...         2.37
# CCH23221      1.50      2.30      2.11      1.96    ...         2.09
# CCQ71947      1.59      1.82      1.85      1.04    ...         2.46
# CCQ71983      2.37      1.57      1.42      1.80    ...         2.44
# CDJ79889      2.09      2.39      2.19      2.43    ...         1.04
#
# pid2      CAP45718  CAP49183  CAP49192  CCD31011  CCH23216  CCH23221  \
# pid1
# AAA43090      1.88      2.31      2.06      2.13      1.51      1.67
# AAA43117      2.47      2.73      2.36      2.70      1.97      1.60
# AAA43185      1.82      2.23      1.75      1.82      1.47      1.80
# AAA43205      1.78      2.15      1.54      1.79      1.31      1.98
# AAA43243      1.74      2.11      1.62      1.94      1.41      1.88
# AAA43247      1.87      2.12      1.72      1.87      1.32      1.68
# AAA43248      2.09      2.62      2.24      2.24      1.55      1.50
# AAA43578      1.20      1.75      1.84      1.25      1.44      2.30
# AAA43678      0.84      1.39      1.61      1.15      1.38      2.11
# AAA72339      1.72      2.03      1.42      1.49      0.59      1.96
# AAA92280      1.70      1.80      1.14      1.54      0.98      1.94
# AAC54377      2.55      2.88      2.91      2.62      2.47      2.57
# AAC54378      1.70      2.10      1.68      1.77      1.49      1.95
# AAC54380      2.57      2.92      2.84      2.84      2.42      2.35
# AAC59602      2.44      2.71      2.62      2.65      2.25      2.06
# AAD05216      1.67      1.21      1.77      1.81      2.17      2.65
# AAD05217      1.38      1.45      1.77      1.39      1.92      2.52
# AAD05218      1.46      1.39      1.76      1.43      1.84      2.42
# AAD17229      1.81      2.05      1.50      1.90      0.87      1.70
# AAD25309      1.70      1.67      1.13      1.60      1.18      2.08
# AAD25312      1.74      1.88      2.28      1.93      1.62      2.11
# AAD26938      2.95      2.96      3.06      3.17      2.61      2.55
# AAF87283      1.32      1.41      1.56      1.30      1.37      2.10
# AAF87284      1.41      1.21      1.29      1.22      1.72      2.42
# AAG10650      2.74      2.96      2.92      2.84      2.49      2.33
# AAG10670      2.57      2.87      2.92      2.74      2.47      2.58
# AAK70452      1.65      1.78      1.93      1.69      1.66      2.12
# AAK70454      1.71      1.64      1.83      1.42      1.77      2.50
# AAK70456      1.71      1.54      1.80      1.54      1.87      2.59
# AAK71687      1.59      1.27      1.52      1.32      1.97      2.67
# ...            ...       ...       ...       ...       ...       ...
# BAN14745      2.60      2.91      2.79      2.68      2.29      2.14
# BAN14747      2.31      2.57      2.38      2.54      2.29      2.11
# BAN42578      0.90      1.41      1.73      1.15      1.70      2.62
# BAN66743      2.30      2.56      2.34      2.31      1.80      0.45
# BAN79067      1.16      1.24      1.60      1.45      2.07      2.77
# BAN81923      1.01      1.38      1.70      1.17      1.68      2.54
# BAO10666      2.41      2.70      2.34      2.38      1.72      1.04
# BAO56967      2.29      2.34      2.29      2.30      2.26      2.23
# BAO74193      0.83      1.48      1.69      1.06      1.75      2.42
# CAA24271      2.36      2.64      2.55      2.66      2.31      2.21
# CAA24272      1.88      2.02      1.48      1.78      1.08      1.69
# CAA29337      2.43      2.71      2.57      2.54      2.16      2.17
# CAA78263      2.46      2.76      2.83      2.68      2.54      2.39
# CAA91080      1.74      1.39      1.69      1.65      1.87      2.58
# CAA91081      1.84      2.05      1.46      1.74      1.01      1.68
# CAB95856      2.17      2.42      1.89      1.92      1.62      1.13
# CAB95857      2.36      2.64      2.31      2.36      1.79      0.72
# CAC18524      1.56      1.56      1.88      1.75      2.10      2.61
# CAC81018      2.40      2.51      2.48      2.62      2.38      2.13
# CAC86610      1.67      1.70      1.15      1.48      0.74      1.86
# CAD20336      2.34      2.70      2.60      2.46      2.37      2.09
# CAP45718      0.00      1.40      1.78      1.27      1.67      2.33
# CAP49183      1.40      0.00      1.58      1.33      2.07      2.62
# CAP49192      1.78      1.58      0.00      1.57      1.44      2.26
# CCD31011      1.27      1.33      1.57      0.00      1.48      2.27
# CCH23216      1.67      2.07      1.44      1.48      0.00      1.82
# CCH23221      2.33      2.62      2.26      2.27      1.82      0.00
# CCQ71947      2.05      2.20      1.62      1.93      0.94      1.77
# CCQ71983      1.57      1.54      1.81      1.53      1.81      2.56
# CDJ79889      2.31      2.63      2.54      2.54      2.28      2.15
#
# pid2      CCQ71947  CCQ71983  CDJ79889
# pid1
# AAA43090      1.53      2.36      2.18
# AAA43117      1.65      2.55      2.30
# AAA43185      1.58      2.11      2.16
# AAA43205      1.53      2.07      2.22
# AAA43243      1.59      1.88      2.23
# AAA43247      1.56      2.00      2.08
# AAA43248      1.59      2.37      2.09
# AAA43578      1.82      1.57      2.39
# AAA43678      1.85      1.42      2.19
# AAA72339      1.04      1.80      2.43
# AAA92280      1.34      1.87      2.32
# AAC54377      2.63      2.52      2.02
# AAC54378      1.30      2.04      2.22
# AAC54380      2.43      2.62      2.02
# AAC59602      2.38      2.55      1.22
# AAD05216      2.25      1.08      2.57
# AAD05217      2.32      0.81      2.41
# AAD05218      2.13      0.84      2.33
# AAD17229      0.90      2.12      2.35
# AAD25309      1.44      1.87      2.48
# AAD25312      1.74      2.01      2.42
# AAD26938      2.59      2.93      2.41
# AAF87283      1.78      1.70      2.28
# AAF87284      1.97      1.52      2.49
# AAG10650      2.62      2.70      2.06
# AAG10670      2.67      2.58      1.99
# AAK70452      1.78      1.15      2.31
# AAK70454      2.17      0.42      2.41
# AAK70456      2.22      0.32      2.42
# AAK71687      2.23      1.66      2.64
# ...            ...       ...       ...
# BAN14745      2.33      2.54      1.15
# BAN14747      2.36      2.43      0.94
# BAN42578      2.14      1.60      2.42
# BAN66743      1.78      2.57      2.20
# BAN79067      2.33      1.60      2.59
# BAN81923      2.13      1.45      2.37
# BAO10666      1.74      2.54      2.22
# BAO56967      2.30      2.15      1.11
# BAO74193      2.12      1.65      2.39
# CAA24271      2.36      2.45      1.11
# CAA24272      1.04      2.15      2.21
# CAA29337      2.31      2.58      1.26
# CAA78263      2.59      2.55      1.98
# CAA91080      2.24      0.50      2.43
# CAA91081      1.01      2.11      2.29
# CAB95856      1.88      2.15      2.30
# CAB95857      1.67      2.50      2.22
# CAC18524      2.20      1.39      2.48
# CAC81018      2.40      2.28      1.19
# CAC86610      1.15      1.79      2.27
# CAD20336      2.46      2.44      1.04
# CAP45718      2.05      1.57      2.31
# CAP49183      2.20      1.54      2.63
# CAP49192      1.62      1.81      2.54
# CCD31011      1.93      1.53      2.54
# CCH23216      0.94      1.81      2.28
# CCH23221      1.77      2.56      2.15
# CCQ71947      0.00      2.20      2.40
# CCQ71983      2.20      0.00      2.33
# CDJ79889      2.40      2.33      0.00
#
# [1198 rows x 1198 columns]

# %%
# Table subselection for testing

n_init_m = 0
n_end_m = len(df_m.index)
selection_m = df_m.ix[n_init_m:n_end_m, n_init_m:n_end_m]
#d = maps_c.sero.to_dict()
#subtype_group = maps_c.groupby('sero').size()
#subtype_group = maps_m.groupby('sero').size()
#selection_m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-67f1bbbd9c09> in <module>()
#       2
#       3 n_init_m = 0
# ----> 4 n_end_m = len(df_m.index)
#       5 selection_m = df_m.ix[n_init_m:n_end_m, n_init_m:n_end_m]
#       6 #d = maps_c.sero.to_dict()
#
# NameError: name 'df_m' is not defined

# %% [markdown]
# ### Calculating median distance for serotypes

# %% [markdown]
# The sub_matrix function allows the selection of a submatrix given the entire matrix (e.g. selection_m) and a selected group of entries (e.g. gp_m extracted from gps_m)

# %%
def sub_matrix(gp, selection): 
    data = pd.merge(gp, selection, right_on=selection.index, left_on=gp.index, how='inner')
    data = data.rename(columns={'key_0':'p_id'})
    data = data.set_index(['p_id'])
    data = data.sort(['sero',], ascending=[0])
    data = data.reindex(columns=data.index)
    return data

gp_m = gps_m[1]
data_m = sub_matrix(gp_m, selection_m)
data_m
# Out:
# p_id      BAF43466
# p_id
# BAF43466         0

# %% [markdown]
# ### Mann-Whitney-Wilcoxon (MWW) RankSum test

# %% [markdown]
# The MWW RankSum test is a useful test to determine if two distributions are significantly different or not. Unlike the t-test, the RankSum test does not assume that the data are normally distributed, potentially providing a more accurate assessment of the data sets. If P <= 0.05, we are highly confident that the distributions significantly differ while with P > 0.05, we must say that the distributions do not significantly differ.

# %%
from pandas import *
from scipy import stats
import random, scipy


def sub_matrix(gp, selection):
    data = pd.merge(gp, selection, right_on=selection.index, left_on=gp.index, how='inner')
    data = data.rename(columns={'key_0':'p_id'})
    data = data.set_index(['p_id'])
    data = data.sort(['sero',], ascending=[0])
    data = data.reindex(columns=data.index)
    return data

def MWW(m, c, l):
    cm = np.triu(c.as_matrix())
    mm = np.triu(m.as_matrix())
    
    z_stat, p_val = stats.mannwhitneyu(c, m)
    print ("crystal_mean:%s, model_mean:%s, MWW value:%s %s" %(np.mean(cm), np.mean(mm), p_val, l))
    
#H2N2 (gps_m; cps_c) = (7; 12) *
#H2N5 ... = (15; )
#H7N3 ... = (17; 18) *
#H5N1 ... = (22; 10) *
#H5N5 ... = (2; )
#H5N2 ... = (12; )
#H3N8 ... = (3; 11) *
#H3N2 ... = (32; 9) *
#H3N6 ... = (20; )
#H2N3 ... = (6; )
#H9N2 ... = (23; )
#H10N7 ... = (11; )
#H7N7 ... = (27; 5) *
#H7N9 ... = (; 2)
#H1N1 ... = (29; 7) *
#H1N2 ... = (34; )

def omogenize(gps_m, gps_c):
    l = min([len(gps_m), len(gps_c)])
    gp_m = gps_m.ix[random.sample(list(gps_m.index), l)]
    gp_c = gps_c.ix[random.sample(list(gps_c.index), l)]
    
    return gp_m, gp_c, l

gp_m, gp_c, l = omogenize(gps_m[22], gps_c[10])
    
data_m = sub_matrix(gp_m, selection_m)
ref_m = data_m.index
cl_m = [maps_m.sero[i] for i in ref_m]

data_c = sub_matrix(gp_c, selection_c)
ref_c = data_c.index
cl_c = [maps_c.sero[i] for i in ref_c]

#MWW(data_m, data_c, l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4feb82adc3c4> in <module>()
#      43     return gp_m, gp_c, l
#      44
# ---> 45 gp_m, gp_c, l = omogenize(gps_m[22], gps_c[10])
#      46
#      47 data_m = sub_matrix(gp_m, selection_m)
#
# NameError: name 'gps_c' is not defined

# %%
# Merging data with id-serotype map

data = pd.merge(maps_c, df_c, right_on=selection_c.index, left_on=maps_c.index, how='inner')
data = data.rename(columns={'key_0':'p_id'})
data = data.set_index(['p_id'])

# Ordering by serotype and repositioning columns with respect to new row position
data = data.sort(['sero',], ascending=[0])
data = data.reindex(columns=data.index)

# Write in a output file

#handle = open('pdb_list_long.txt', 'w')
#for d in df_c.index:
#    print (d)
#    handle.write(d + '\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7d07ad68fed5> in <module>()
#       1 # Merging data with id-serotype map
#       2
# ----> 3 data = pd.merge(maps_c, df_c, right_on=selection_c.index, left_on=maps_c.index, how='inner')
#       4 data = data.rename(columns={'key_0':'p_id'})
#       5 data = data.set_index(['p_id'])
#
# NameError: name 'maps_c' is not defined

# %%
# Export table and list to csv files ...
#data.to_csv('sorted_table_2', sep='\t')

# %%
# Take the class names (ref and cl lists can be used for serotype/protein data labeling)
ref = data.index
cl = [maps.sero[i] for i in ref]
data.index

# This doesn't work, report the bug to developers
#
#ref_class = open('ref_class.txt', 'a')
#[ref_class.write('%s\n' %j) for j in cl]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-b4a3d11cc3e9> in <module>()
#       1 # Take the class names (ref and cl lists can be used for serotype/protein data labeling)
#       2 ref = data.index
# ----> 3 cl = [maps.sero[i] for i in ref]
#       4 data.index
#       5
#
# <ipython-input-38-b4a3d11cc3e9> in <listcomp>(.0)
#       1 # Take the class names (ref and cl lists can be used for serotype/protein data labeling)
#       2 ref = data.index
# ----> 3 cl = [maps.sero[i] for i in ref]
#       4 data.index
#       5
#
# NameError: name 'maps' is not defined

# %%
# Cell for plotting heatmap
def plot():
    # %matplotlib inline
    fig = plt.figure(figsize=(50, 50), dpi=100)

    plt.pcolor(data, cmap=plt.cm.Blues)
    #plt.xticks(np.arange(min(data.index), max(data.index)+10, fontsize=30))
    plt.xticks(np.arange(0.5, len(data.index), 1), cl, fontsize=5, rotation='vertical')
    plt.yticks(np.arange(0.5, len(data.columns), 1), cl, fontsize=5, rotation='horizontal')
    #plt.show()
    
    fig1 = plt.gcf()
    plt.show()
    plt.draw()
    #fig1.savefig('tessstttyyy.png', dpi=300)
    
#plot()
