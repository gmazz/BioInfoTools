# %% [markdown]
# ### Displaying distance matrices

# %% [markdown]
# Read csv tables and display distrance matrices among objects (i.e. RMSD values between all proteins)

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt

# %%
df_m = pd.read_csv('./data/models_v1/RMSD_scores_global_tab.csv', index_col='p_id')
maps_m = pd.read_csv('./data/models_v1/models_sero_out.csv', index_col='p_id')
gb_m = maps_m.groupby('sero')
gps_m = [gb_m.get_group(x) for x in gb_m.groups]
maps = pd.read_csv('./data/models_v1/id_classes.csv', index_col='p_id')

# %%
score_list = pd.read_csv('./data/models_v2/new_models_scores/', index_col='pid1')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-0534c6158c51> in <module>()
# ----> 1 score_list = pd.read_csv('./data/models_v2/new_models_scores/new_models_scores.csv', index_col='pid1')
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     463                     skip_blank_lines=skip_blank_lines)
#     464
# --> 465         return _read(filepath_or_buffer, kwds)
#     466
#     467     parser_f.__name__ = name
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     239
#     240     # Create the parser.
# --> 241     parser = TextFileReader(filepath_or_buffer, **kwds)
#     242
#     243     if (nrows is not None) and (chunksize is not None):
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     555             self.options['has_index_names'] = kwds['has_index_names']
#     556
# --> 557         self._make_engine(self.engine)
#     558
#     559     def _get_options_with_defaults(self, engine):
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     692     def _make_engine(self, engine='c'):
#     693         if engine == 'c':
# --> 694             self._engine = CParserWrapper(self.f, **self.options)
#     695         else:
#     696             if engine == 'python':
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1059         kwds['allow_leading_cols'] = self.index_col is not False
#    1060
# -> 1061         self._reader = _parser.TextReader(src, **kwds)
#    1062
#    1063         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3150)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5772)()
#
# IOError: File ./data/models_v2/new_models_scores/new_models_scores.csv does not exist

# %%
# Table subselection for testing

n_init_m = 0
n_end_m = len(df_m.index)
selection_m = df_m.ix[n_init_m:n_end_m, n_init_m:n_end_m]
#d = maps_c.sero.to_dict()
#subtype_group = maps_c.groupby('sero').size()
#subtype_group = maps_m.groupby('sero').size()
selection_m
# Out:
#           AAA43090  AAA43117  AAA43185  AAA43205  AAA43243  AAA43247  \
# p_id
# AAA43090      0.00      0.11      0.11      1.02      0.10      0.13
# AAA43117      0.11      0.00      0.12      1.02      0.08      0.12
# AAA43185      0.11      0.12      0.00      1.03      0.12      0.13
# AAA43205      1.02      1.02      1.03      0.00      1.02      1.02
# AAA43243      0.10      0.08      0.12      1.02      0.00      0.12
# AAA43247      0.13      0.12      0.13      1.02      0.12      0.00
# AAA43248      0.13      0.11      0.14      1.02      0.12      0.15
# AAA43578      0.12      0.11      0.13      1.03      0.12      0.09
# AAA43678      0.14      0.13      0.13      1.03      0.13      0.08
# AAA72339      1.09      1.09      1.10      0.76      1.09      1.10
# AAA92280      1.07      1.07      1.08      0.81      1.07      1.07
# AAC54377      1.76      1.77      1.76      1.72      1.76      1.75
# AAC54378      1.04      1.04      1.06      0.14      1.05      1.05
# AAC54380      1.76      1.77      1.77      1.72      1.76      1.75
# AAC59602      1.81      1.81      1.80      1.73      1.81      1.79
# AAD05216      0.94      0.94      0.95      1.09      0.94      0.95
# AAD05217      1.01      1.01      1.02      0.98      1.01      1.02
# AAD05218      1.09      1.09      1.10      0.91      1.09      1.10
# AAD17229      0.98      0.98      0.99      0.84      0.98      0.99
# AAD25309      1.01      1.01      1.02      0.80      1.01      1.01
# AAD25312      1.06      1.07      1.08      0.81      1.07      1.07
# AAD26938      1.77      1.77      1.77      1.72      1.76      1.76
# AAF87283      1.05      1.05      1.06      0.80      1.05      1.05
# AAF87284      1.06      1.07      1.08      0.80      1.07      1.07
# AAG10650      1.75      1.76      1.76      1.71      1.75      1.74
# AAG10670      1.75      1.75      1.75      1.71      1.74      1.74
# AAK70452      1.11      1.11      1.12      0.96      1.11      1.12
# AAK70454      1.05      1.05      1.06      1.02      1.05      1.06
# AAK70456      1.04      1.03      1.04      0.97      1.04      1.04
# AAK71687      1.07      1.07      1.08      0.80      1.07      1.08
# ...            ...       ...       ...       ...       ...       ...
# GQ249333      0.97      0.97      0.98      1.09      0.96      0.97
# GQ303340      0.97      0.97      0.98      1.09      0.96      0.97
# GQ338084      1.04      1.04      1.05      0.16      1.04      1.05
# GQ457487      0.96      0.96      0.97      1.09      0.95      0.97
# AAD25309      0.83      0.82      0.83
# AAD25312      0.84      0.83      0.83
# AAD26938      1.72      1.73      1.72
# AAF87283      0.82      0.81      0.81
# AAF87284      0.81      0.80      0.81
# AAG10650      1.71      1.72      1.72
# AAG10670      1.70      1.72      1.71
# AAK70452      1.04      0.98      1.03
# AAK70454      1.09      1.04      1.09
# AAK70456      1.04      0.99      1.04
# AAK71687      0.81      0.80      0.80
# ...            ...       ...       ...
# GQ249333      1.11      1.10      1.11
# GQ303340      1.11      1.11      1.11
# GQ338084      0.14      0.11      0.17
# GQ457487      1.11      1.10      1.11
# GU045582      1.11      1.10      1.11
# GU367325      1.11      1.11      1.12
# GU596984      0.16      0.12      0.18
# GU727669      0.21      0.21      0.23
# HM581919      1.12      1.11      1.12
# JF719758      1.12      1.12      1.13
# JN187143      1.12      1.11      1.12
# JN187147      1.13      1.12      1.13
# JN582041      0.20      0.17      0.23
# JN588809      0.20      0.17      0.21
# JN588810      0.16      0.11      0.17
# JN807782      0.22      0.18      0.24
# JN807830      0.13      0.10      0.14
# JN807843      0.18      0.16      0.20
# JN807846      0.15      0.18      0.13
# JN807851      0.16      0.21      0.16
# JN986882      0.22      0.19      0.22
# JQ065159      1.12      1.11      1.13
# JQ065166      1.12      1.12      1.13
# JQ277225      0.14      0.10      0.16
# JQ365025      1.10      1.09      1.10
# JQ396219      1.11      1.10      1.12
# JQ858472      0.20      0.17      0.21
# JQ858483      0.00      0.14      0.10
# JX021305      0.14      0.00      0.15
# JX456104      0.10      0.15      0.00
#
# [1203 rows x 1203 columns]

# %% [markdown]
# ### Calculating median distance for serotypes

# %% [markdown]
# The sub_matrix function allows the selection of a submatrix given the entire matrix (e.g. selection_m) and a selected group of entries (e.g. gp_m extracted from gps_m)

# %%
def sub_matrix(gp, selection): 
    data = pd.merge(gp, selection, right_on=selection.index, left_on=gp.index, how='inner')
    data = data.rename(columns={'key_0':'p_id'})
    data = data.set_index(['p_id'])
    data = data.sort(['sero',], ascending=[0])
    data = data.reindex(columns=data.index)
    return data

gp_m = gps_m[1]
data_m = sub_matrix(gp_m, selection_m)
data_m
# Out:
# p_id      BAF43466
# p_id
# BAF43466         0

# %% [markdown]
# ### Mann-Whitney-Wilcoxon (MWW) RankSum test

# %% [markdown]
# The MWW RankSum test is a useful test to determine if two distributions are significantly different or not. Unlike the t-test, the RankSum test does not assume that the data are normally distributed, potentially providing a more accurate assessment of the data sets. If P <= 0.05, we are highly confident that the distributions significantly differ while with P > 0.05, we must say that the distributions do not significantly differ.

# %%
from pandas import *
from scipy import stats
import random, scipy


def sub_matrix(gp, selection):
    data = pd.merge(gp, selection, right_on=selection.index, left_on=gp.index, how='inner')
    data = data.rename(columns={'key_0':'p_id'})
    data = data.set_index(['p_id'])
    data = data.sort(['sero',], ascending=[0])
    data = data.reindex(columns=data.index)
    return data

def MWW(m, c, l):
    cm = np.triu(c.as_matrix())
    mm = np.triu(m.as_matrix())
    
    z_stat, p_val = stats.mannwhitneyu(c, m)
    print ("crystal_mean:%s, model_mean:%s, MWW value:%s %s" %(np.mean(cm), np.mean(mm), p_val, l))
    
#H2N2 (gps_m; cps_c) = (7; 12) *
#H2N5 ... = (15; )
#H7N3 ... = (17; 18) *
#H5N1 ... = (22; 10) *
#H5N5 ... = (2; )
#H5N2 ... = (12; )
#H3N8 ... = (3; 11) *
#H3N2 ... = (32; 9) *
#H3N6 ... = (20; )
#H2N3 ... = (6; )
#H9N2 ... = (23; )
#H10N7 ... = (11; )
#H7N7 ... = (27; 5) *
#H7N9 ... = (; 2)
#H1N1 ... = (29; 7) *
#H1N2 ... = (34; )

def omogenize(gps_m, gps_c):
    l = min([len(gps_m), len(gps_c)])
    gp_m = gps_m.ix[random.sample(list(gps_m.index), l)]
    gp_c = gps_c.ix[random.sample(list(gps_c.index), l)]
    
    return gp_m, gp_c, l

gp_m, gp_c, l = omogenize(gps_m[22], gps_c[10])
    
data_m = sub_matrix(gp_m, selection_m)
ref_m = data_m.index
cl_m = [maps_m.sero[i] for i in ref_m]

data_c = sub_matrix(gp_c, selection_c)
ref_c = data_c.index
cl_c = [maps_c.sero[i] for i in ref_c]

#MWW(data_m, data_c, l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4feb82adc3c4> in <module>()
#      43     return gp_m, gp_c, l
#      44
# ---> 45 gp_m, gp_c, l = omogenize(gps_m[22], gps_c[10])
#      46
#      47 data_m = sub_matrix(gp_m, selection_m)
#
# NameError: name 'gps_c' is not defined

# %%
# Merging data with id-serotype map

data = pd.merge(maps_c, df_c, right_on=selection_c.index, left_on=maps_c.index, how='inner')
data = data.rename(columns={'key_0':'p_id'})
data = data.set_index(['p_id'])

# Ordering by serotype and repositioning columns with respect to new row position
data = data.sort(['sero',], ascending=[0])
data = data.reindex(columns=data.index)

# Write in a output file

#handle = open('pdb_list_long.txt', 'w')
#for d in df_c.index:
#    print (d)
#    handle.write(d + '\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7d07ad68fed5> in <module>()
#       1 # Merging data with id-serotype map
#       2
# ----> 3 data = pd.merge(maps_c, df_c, right_on=selection_c.index, left_on=maps_c.index, how='inner')
#       4 data = data.rename(columns={'key_0':'p_id'})
#       5 data = data.set_index(['p_id'])
#
# NameError: name 'maps_c' is not defined

# %%
# Export table and list to csv files ...
#data.to_csv('sorted_table_2', sep='\t')

# %%
# Take the class names (ref and cl lists can be used for serotype/protein data labeling)
ref = data.index
cl = [maps.sero[i] for i in ref]
data.index

# This doesn't work, report the bug to developers
#
#ref_class = open('ref_class.txt', 'a')
#[ref_class.write('%s\n' %j) for j in cl]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-b4a3d11cc3e9> in <module>()
#       1 # Take the class names (ref and cl lists can be used for serotype/protein data labeling)
#       2 ref = data.index
# ----> 3 cl = [maps.sero[i] for i in ref]
#       4 data.index
#       5
#
# <ipython-input-38-b4a3d11cc3e9> in <listcomp>(.0)
#       1 # Take the class names (ref and cl lists can be used for serotype/protein data labeling)
#       2 ref = data.index
# ----> 3 cl = [maps.sero[i] for i in ref]
#       4 data.index
#       5
#
# NameError: name 'maps' is not defined

# %%
# Cell for plotting heatmap
def plot():
    # %matplotlib inline
    fig = plt.figure(figsize=(50, 50), dpi=100)

    plt.pcolor(data, cmap=plt.cm.Blues)
    #plt.xticks(np.arange(min(data.index), max(data.index)+10, fontsize=30))
    plt.xticks(np.arange(0.5, len(data.index), 1), cl, fontsize=5, rotation='vertical')
    plt.yticks(np.arange(0.5, len(data.columns), 1), cl, fontsize=5, rotation='horizontal')
    #plt.show()
    
    fig1 = plt.gcf()
    plt.show()
    plt.draw()
    #fig1.savefig('tessstttyyy.png', dpi=300)
    
#plot()
